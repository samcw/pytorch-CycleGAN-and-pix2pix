# %%
import matplotlib.pyplot as plt
import numpy as np
import itertools

from openpyxl import load_workbook

plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %%
def plot_Matrix(cm, classes, title=None,  cmap=plt.cm.Blues):
    
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax) # 侧边的颜色条带
    
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='真实值',
           xlabel='预测值')

    # 通过绘制格网，模拟每个单元格的边框
    ax.set_xticks(np.arange(cm.shape[1]+1)-.5, minor=True)
    ax.set_yticks(np.arange(cm.shape[0]+1)-.5, minor=True)
    ax.grid(which="minor", color="gray", linestyle='-', linewidth=0.2)
    ax.tick_params(which="minor", bottom=False, left=False)

    # 将x轴上的lables旋转45度
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # 标注百分比信息
    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j]), 
                 horizontalalignment="center",
                 verticalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('真实值')
    plt.xlabel('预测值')
    plt.savefig('confusion_matrix.png', dpi=256)

# %%
wb = load_workbook('../confusion_matrix.xlsx')
sheet = wb['Sheet1']
wb.close()
array = []
for row in sheet['A1:K11']:
    _row = []
    for cell in row:
        _row.append(cell.value)
    array.append(_row)
# 类别
classes = array.pop(0)
classes.pop(0)
# 去除矩阵其他值
cm = []
for row in array:
    row.pop(0)
    _row = []
    for cell in row:
        _row.append(float(cell))
    cm.append(_row)
cm = np.array(cm)

plot_Matrix(cm, classes)
# Out:
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 32454 (\N{CJK UNIFIED IDEOGRAPH-7EC6}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 33740 (\N{CJK UNIFIED IDEOGRAPH-83CC}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 24615 (\N{CJK UNIFIED IDEOGRAPH-6027}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 26001 (\N{CJK UNIFIED IDEOGRAPH-6591}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 28857 (\N{CJK UNIFIED IDEOGRAPH-70B9}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 30149 (\N{CJK UNIFIED IDEOGRAPH-75C5}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 26089 (\N{CJK UNIFIED IDEOGRAPH-65E9}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 30123 (\N{CJK UNIFIED IDEOGRAPH-75AB}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 20581 (\N{CJK UNIFIED IDEOGRAPH-5065}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 24247 (\N{CJK UNIFIED IDEOGRAPH-5EB7}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 26202 (\N{CJK UNIFIED IDEOGRAPH-665A}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 21494 (\N{CJK UNIFIED IDEOGRAPH-53F6}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 38665 (\N{CJK UNIFIED IDEOGRAPH-9709}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 26543 (\N{CJK UNIFIED IDEOGRAPH-67AF}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 20108 (\N{CJK UNIFIED IDEOGRAPH-4E8C}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 34728 (\N{CJK UNIFIED IDEOGRAPH-87A8}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 36718 (\N{CJK UNIFIED IDEOGRAPH-8F6E}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 33457 (\N{CJK UNIFIED IDEOGRAPH-82B1}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 40644 (\N{CJK UNIFIED IDEOGRAPH-9EC4}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 26354 (\N{CJK UNIFIED IDEOGRAPH-66F2}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 39044 (\N{CJK UNIFIED IDEOGRAPH-9884}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 27979 (\N{CJK UNIFIED IDEOGRAPH-6D4B}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 30495 (\N{CJK UNIFIED IDEOGRAPH-771F}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:32: UserWarning: Glyph 23454 (\N{CJK UNIFIED IDEOGRAPH-5B9E}) missing from current font.
#   plt.tight_layout()
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 32454 (\N{CJK UNIFIED IDEOGRAPH-7EC6}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 33740 (\N{CJK UNIFIED IDEOGRAPH-83CC}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 24615 (\N{CJK UNIFIED IDEOGRAPH-6027}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 26001 (\N{CJK UNIFIED IDEOGRAPH-6591}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 28857 (\N{CJK UNIFIED IDEOGRAPH-70B9}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 30149 (\N{CJK UNIFIED IDEOGRAPH-75C5}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 26089 (\N{CJK UNIFIED IDEOGRAPH-65E9}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 30123 (\N{CJK UNIFIED IDEOGRAPH-75AB}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 20581 (\N{CJK UNIFIED IDEOGRAPH-5065}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 24247 (\N{CJK UNIFIED IDEOGRAPH-5EB7}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 26202 (\N{CJK UNIFIED IDEOGRAPH-665A}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 21494 (\N{CJK UNIFIED IDEOGRAPH-53F6}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 38665 (\N{CJK UNIFIED IDEOGRAPH-9709}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 26543 (\N{CJK UNIFIED IDEOGRAPH-67AF}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 20108 (\N{CJK UNIFIED IDEOGRAPH-4E8C}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 34728 (\N{CJK UNIFIED IDEOGRAPH-87A8}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 36718 (\N{CJK UNIFIED IDEOGRAPH-8F6E}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 33457 (\N{CJK UNIFIED IDEOGRAPH-82B1}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 40644 (\N{CJK UNIFIED IDEOGRAPH-9EC4}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 26354 (\N{CJK UNIFIED IDEOGRAPH-66F2}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 39044 (\N{CJK UNIFIED IDEOGRAPH-9884}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 27979 (\N{CJK UNIFIED IDEOGRAPH-6D4B}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 30495 (\N{CJK UNIFIED IDEOGRAPH-771F}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
# C:\Users\EruHi\AppData\Local\Temp\ipykernel_10076\554148058.py:35: UserWarning: Glyph 23454 (\N{CJK UNIFIED IDEOGRAPH-5B9E}) missing from current font.
#   plt.savefig('confusion_matrix.png', dpi=256)
